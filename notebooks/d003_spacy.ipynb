# %%
import spacy
import pandas as pd

# %%
nlp = spacy.load('en_core_web_md')

df = pd.read_csv('../data/train_new.csv', na_filter=False)
X_text = df['comment_text'].values

del(df)

# %%
doc = nlp(X_text[0].decode('utf8'))

# %%
records = ((token.text, token.lemma_, token.pos_, token.tag_, token.dep_, token.shape_, token.is_alpha, token.is_stop)
           for token in doc)

columns = ["TEXT","LEMMA","POS","TAG","DEP","SHAPE","ALPHA","STOP"]

pd.DataFrame.from_records(records, columns=columns)
# Out:
#                 TEXT             LEMMA    POS   TAG        DEP  \
# 0        Explanation       explanation   NOUN    NN       ROOT
# 1                 \n                \n  SPACE
# 2                Why               why    ADV   WRB     advmod
# 3                the               the    DET    DT        det
# 4              edits              edit   NOUN   NNS      nsubj
# 5               made              make   VERB   VBN        acl
# 6              under             under    ADP    IN       prep
# 7                 my            -PRON-    ADJ  PRP$       poss
# 8           username          username    ADJ    JJ       pobj
# 9           Hardcore          hardcore  PROPN   NNP   compound
# 10         Metallica         metallica  PROPN   NNP   compound
# 11               Fan               fan  PROPN   NNP  nsubjpass
# 12              were                be   VERB   VBD    auxpass
# 13          reverted            revert   VERB   VBN       ROOT
# 14                 ?                 ?  PUNCT     .      punct
# 15              They            -PRON-   PRON   PRP      nsubj
# 16              were                be   VERB   VBD       ROOT
# 17               n't               not    ADV    RB        neg
# 18        vandalisms         vandalism   NOUN   NNS       attr
# 19                 ,                 ,  PUNCT     ,      punct
# 20              just              just    ADV    RB     advmod
# 21           closure           closure   NOUN    NN       attr
# 22                on                on    ADP    IN       prep
# 23              some              some    DET    DT        det
# 24               GAs               gas   NOUN    NN       pobj
# 25             after             after    ADP    IN       mark
# 26                 I            -PRON-   PRON   PRP      nsubj
# 27             voted              vote   VERB   VBD      advcl
# 28                at                at    ADP    IN       prep
# 29               New               new  PROPN   NNP   compound
# 30              York              york  PROPN   NNP   compound
# 31             Dolls             dolls  PROPN   NNP   compound
# 32               FAC               fac  PROPN   NNP       pobj
# 33                 .                 .  PUNCT     .      punct
# 34               And               and  CCONJ    CC         cc
# 35            please            please   INTJ    UH       intj
# 36                do                do   VERB    VB        aux
# 37               n't               not    ADV    RB        neg
# 38            remove            remove   VERB    VB       ROOT
# 39               the               the    DET    DT        det
# 40          template          template   NOUN    NN       dobj
# 41              from              from    ADP    IN       prep
# 42               the               the    DET    DT        det
# 43              talk              talk   NOUN    NN   compound
# 44              page              page   NOUN    NN       pobj
# 45             since             since    ADP    IN       mark
# 46                 I            -PRON-   PRON   PRP  nsubjpass
# 47                'm                be   VERB   VBP    auxpass
# 48           retired            retire   VERB   VBN      advcl
# 49  now.89.205.38.27  now.89.205.38.27   NOUN   NNS       ROOT
#
#                SHAPE  ALPHA   STOP
# 0              Xxxxx   True  False
# 1                 \n  False  False
# 2                Xxx   True  False
# 3                xxx   True  False
# 4               xxxx   True  False
# 5               xxxx   True  False
# 6               xxxx   True  False
# 7                 xx   True  False
# 8               xxxx   True  False
# 9              Xxxxx   True  False
# 10             Xxxxx   True  False
# 11               Xxx   True  False
# 12              xxxx   True  False
# 13              xxxx   True  False
# 14                 ?  False  False
# 15              Xxxx   True  False
# 16              xxxx   True  False
# 17               x'x  False  False
# 18              xxxx   True  False
# 19                 ,  False  False
# 20              xxxx   True  False
# 21              xxxx   True  False
# 22                xx   True  False
# 23              xxxx   True  False
# 24               XXx   True  False
# 25              xxxx   True  False
# 26                 X   True  False
# 27              xxxx   True  False
# 28                xx   True  False
# 29               Xxx   True  False
# 30              Xxxx   True  False
# 31             Xxxxx   True  False
# 32               XXX   True  False
# 33                 .  False  False
# 34               Xxx   True  False
# 35              xxxx   True  False
# 36                xx   True  False
# 37               x'x  False  False
# 38              xxxx   True  False
# 39               xxx   True  False
# 40              xxxx   True  False
# 41              xxxx   True  False
# 42               xxx   True  False
# 43              xxxx   True  False
# 44              xxxx   True  False
# 45              xxxx   True  False
# 46                 X   True  False
# 47                'x  False  False
# 48              xxxx   True  False
# 49  xxx.dd.ddd.dd.dd  False  False

# %%
records = ((ent.text, ent.start_char, ent.end_char, ent.label_) for ent in doc.ents)

columns = ["TEXT","START_CHAR","END_CHAR","LABEL_"]

pd.DataFrame.from_records(records, columns=columns)
# Out:
#                  TEXT  START_CHAR  END_CHAR LABEL_
# 0  New York Dolls FAC         154       172    ORG

# %%
for(ent.text, ent.start_char, ent.end_char, ent.label_)
